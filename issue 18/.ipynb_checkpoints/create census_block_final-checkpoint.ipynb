# %%
import pandas as pd

# %%
df = pd.read_csv('census_block.csv')

# %%
pd.options.display.float_format = '{}'.format

# %%
#test length of df
len(df)
# Out:
# 86853

# %%
#test length of df where geometry == geometry.1
len(df[df['geometry']==df['geometry.1']])
# Out:
# 86853

# %%
columns = ['GEOID10', 'inspection_id', 'latitude', 'longitude']

# %%
new_df = df[columns]

# %%
new_df
# Out:
#                 GEOID10  inspection_id           latitude          longitude
# 0     110010055004000.0              1          38.909636         -77.047744
# 1     110010011001009.0              2          38.963665           -77.0749
# 2     110010011001009.0              3          38.963665           -77.0749
# 3     110010089031005.0              4          38.905549         -76.976949
# 4     110010044002015.0              5          38.914838 -77.02404200000001
# 5     110010044002015.0              6          38.914838 -77.02404200000001
# 6     110010064002007.0              7          38.869555          -77.01309
# 7     110010002022000.0              8          38.910629 -77.06541899999999
# 8     110010076052004.0              9          38.861363         -76.969184
# 9     110010006002001.0             10            38.9344         -77.057895
# 10    110010006002001.0             11            38.9344         -77.057895
# ...

# %%
new_df.to_csv('census_block_final.csv', index=False)
